# %%
import pymongo
import numpy as np
import pandas as pd
from pymongo import MongoClient
import matplotlib.pyplot as plt
# %matplotlib inline
print("test1")
client = MongoClient("mongodb+srv://admin:1234@cluster0.nlxpy.mongodb.net/dbCovid?retryWrites=true&w=majority")
db = client.dbCovid
data = db.whoData
data = pd.DataFrame(list(data.find()))
# Out:
# test1

# %%
zafdf = data.query('ISO_CODE == "ZAF"')
print("test7")
print("Cumulative Cases in South Africa")
plt.figure(); newdf.plot(x="Date_epicrv", y="TotalCase"); plt.legend(loc='best')
# Out:
# test7
# Cumulative Cases in South Africa

# %%
usadf = data.query('ISO_CODE == "USA"')
print("United States of America")
usadf.plot(kind='bar', stacked=True)
print("USA")
# Out:
# United States of America
# USA

# %%
print("New Daily Cases in USA")
plt.figure()
usadf["NewCase"].diff().hist()
# Out:
# New Daily Cases in USA

# %%
plt.figure()
x = usadf["Date_epicrv"]
y1 = usadf["TotalCase"]
y2 = usadf["TotalDeath"]
plt.plot(x,y1)
plt.plot(x,y2)
